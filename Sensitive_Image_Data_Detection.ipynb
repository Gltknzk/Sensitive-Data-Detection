# %% [markdown]
# # Sensitive Image Data Detection
#
# ## Importing libraries and downloading the dataset

# %%
import tensorflow as tf

tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Importing the necessary libraries
import tensorflow as tf
import numpy as np
import os

# Downloading the dataset
git_folder = "/content/Sensitive-Data-Detection"
if os.path.exists(git_folder) == False:
  # !git clone https://github.com/Gltknzk/Sensitive-Data-Detection.git

training_folder = git_folder + "/dataset/training"
validation_folder = git_folder + "/dataset/validation"

# %%
train_sensitive_dir = os.path.join(training_folder + "/sensitive")
train_nonsensitive_dir = os.path.join(training_folder + "/nonsensitive")
validation_sensitive_dir = os.path.join(validation_folder + "/sensitive")
validation_nonsensitive_dir = os.path.join(validation_folder + "/nonsensitive")

# Image Dataset size
print('Total training sensitive images:', len(os.listdir(train_sensitive_dir)))
print('Total training nonsensitive images:', len(os.listdir(train_nonsensitive_dir)))
print('Total validation sensitive images:', len(os.listdir(validation_sensitive_dir)))
print('Total validation nonsensitive images:', len(os.listdir(validation_nonsensitive_dir)))
# Out:
# Total training sensitive images: 300
# Total training nonsensitive images: 300
# Total validation sensitive images: 50
# Total validation nonsensitive images: 50

# %% [markdown]
# ## Sample Data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

train_sensitive_dir = os.path.join(training_folder+"/sensitive")
train_nonsensitive_dir = os.path.join(training_folder+"/nonsensitive")
train_sensitive_names = os.listdir(train_sensitive_dir)
train_nonsensitive_names = os.listdir(train_nonsensitive_dir)

pic_index += 8
next_sensitive_pix = [os.path.join(train_sensitive_dir, fname) 
                for fname in train_sensitive_names[pic_index-8:pic_index]]
next_nonsensitive_pix = [os.path.join(train_nonsensitive_dir, fname) 
                for fname in train_nonsensitive_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sensitive_pix+next_nonsensitive_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Model

# %%
# Callbacks to cancel training after reaching a desired accuracy
# This is done to avoid overfitting
DESIRED_ACCURACY = 0.99

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print("Reached 99% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# Sequential - defines a SEQUENCE of layers in the neural network.
model = tf.keras.models.Sequential([
  # 2D Convolution Layer - Filter, Kernel_size, activation fn
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  # Max pooling operation for 2D data - Pool size
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flattens the input. Does not affect the batch size.
  tf.keras.layers.Flatten(),
  # Regular densely-connected Neural Network layer with ReLU activation function.
  tf.keras.layers.Dense(512, activation='relu'),
  # Regular densely-connected Neural Network layer with sigmoid activation function.
  tf.keras.layers.Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import RMSprop

# model.compile - Configures the model for training.
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Adam -  optimization algorithm used instead of the classical stochastic gradient descent procedure to update network weights.

# Display the summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 512)               6423040
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,811,969
# Trainable params: 6,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Preprocessing, Data Augmentation & Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescaling - 1/255 is to transform every pixel value from range [0,255] -> [0,1]
# Performing image augmentation for training data
train_datagen = ImageDataGenerator(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# flow_from_directory - Takes the path to a directory & generates batches of data.
train_generator = train_datagen.flow_from_directory(
        training_folder,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        validation_folder,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )

num_epochs = 500
# model.fit - Train the model for a fixed number of epochs
history = model.fit(
      train_generator,
      steps_per_epoch=10,
      epochs=num_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.7174 - accuracy: 0.5667 - val_loss: 0.6284 - val_accuracy: 0.8250
# Epoch 2/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.6123 - accuracy: 0.7100 - val_loss: 0.2954 - val_accuracy: 0.8750
# Epoch 3/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.5850 - accuracy: 0.6633 - val_loss: 0.5000 - val_accuracy: 0.8250
# Epoch 4/500
# 10/10 [==============================] - 4s 361ms/step - loss: 0.5666 - accuracy: 0.7233 - val_loss: 0.4387 - val_accuracy: 0.8250
# Epoch 5/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.4720 - accuracy: 0.8033 - val_loss: 0.5412 - val_accuracy: 0.7500
# Epoch 6/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.4605 - accuracy: 0.7733 - val_loss: 0.4913 - val_accuracy: 0.8000
# Epoch 7/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.4788 - accuracy: 0.7500 - val_loss: 0.3640 - val_accuracy: 0.9250
# Epoch 8/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.4783 - accuracy: 0.7567 - val_loss: 0.3304 - val_accuracy: 0.8500
# Epoch 9/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.5113 - accuracy: 0.7400 - val_loss: 0.3188 - val_accuracy: 0.9000
# Epoch 10/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.4313 - accuracy: 0.8033 - val_loss: 0.2837 - val_accuracy: 0.8750
# Epoch 11/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.4861 - accuracy: 0.7900 - val_loss: 0.3046 - val_accuracy: 0.9000
# Epoch 12/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.4402 - accuracy: 0.8033 - val_loss: 0.2980 - val_accuracy: 0.9000
# Epoch 13/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.5029 - accuracy: 0.7600 - val_loss: 0.4175 - val_accuracy: 0.7500
# Epoch 14/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.4026 - accuracy: 0.8400 - val_loss: 0.2633 - val_accuracy: 0.8750
# Epoch 15/500
# 10/10 [==============================] - 3s 331ms/step - loss: 0.4428 - accuracy: 0.7900 - val_loss: 0.3106 - val_accuracy: 0.8750
# Epoch 16/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.4920 - accuracy: 0.7567 - val_loss: 0.2758 - val_accuracy: 0.9000
# Epoch 17/500
# 10/10 [==============================] - 4s 354ms/step - loss: 0.4360 - accuracy: 0.7967 - val_loss: 0.2248 - val_accuracy: 0.9500
# Epoch 18/500
# 10/10 [==============================] - 3s 356ms/step - loss: 0.3741 - accuracy: 0.8200 - val_loss: 0.1957 - val_accuracy: 0.9000
# Epoch 19/500
# 10/10 [==============================] - 4s 394ms/step - loss: 0.4059 - accuracy: 0.8300 - val_loss: 0.2881 - val_accuracy: 0.9000
# Epoch 20/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.3617 - accuracy: 0.8233 - val_loss: 0.2103 - val_accuracy: 0.9000
# Epoch 21/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.3588 - accuracy: 0.8400 - val_loss: 0.2040 - val_accuracy: 0.9000
# Epoch 22/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.3262 - accuracy: 0.8767 - val_loss: 0.1620 - val_accuracy: 0.9500
# Epoch 23/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.3954 - accuracy: 0.8067 - val_loss: 0.1825 - val_accuracy: 1.0000
# Epoch 24/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.3568 - accuracy: 0.8633 - val_loss: 0.1967 - val_accuracy: 0.9750
# Epoch 25/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.3791 - accuracy: 0.8300 - val_loss: 0.1970 - val_accuracy: 0.9500
# Epoch 26/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.2643 - accuracy: 0.8967 - val_loss: 0.1958 - val_accuracy: 0.9250
# Epoch 27/500
# 10/10 [==============================] - 3s 349ms/step - loss: 0.3412 - accuracy: 0.8533 - val_loss: 0.1254 - val_accuracy: 0.9250
# Epoch 28/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.3594 - accuracy: 0.8533 - val_loss: 0.1469 - val_accuracy: 1.0000
# Epoch 29/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.3452 - accuracy: 0.8667 - val_loss: 0.0970 - val_accuracy: 0.9500
# Epoch 30/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.3429 - accuracy: 0.8667 - val_loss: 0.1408 - val_accuracy: 0.9750
# Epoch 31/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0
500
# 10/10 [==============================] - 4s 357ms/step - loss: 0.1489 - accuracy: 0.9433 - val_loss: 0.0652 - val_accuracy: 0.9750
# Epoch 98/500
# 10/10 [==============================] - 4s 359ms/step - loss: 0.1597 - accuracy: 0.9300 - val_loss: 0.1259 - val_accuracy: 0.9500
# Epoch 99/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1513 - accuracy: 0.9433 - val_loss: 0.0803 - val_accuracy: 0.9750
# Epoch 100/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1542 - accuracy: 0.9467 - val_loss: 0.1591 - val_accuracy: 0.9000
# Epoch 101/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1473 - accuracy: 0.9433 - val_loss: 0.2452 - val_accuracy: 0.9000
# Epoch 102/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1820 - accuracy: 0.9300 - val_loss: 0.3106 - val_accuracy: 0.8750
# Epoch 103/500
# 10/10 [==============================] - 3s 346ms/step - loss: 0.1270 - accuracy: 0.9433 - val_loss: 0.2547 - val_accuracy: 0.8750
# Epoch 104/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.1170 - accuracy: 0.9500 - val_loss: 0.1590 - val_accuracy: 0.9250
# Epoch 105/500
# 10/10 [==============================] - 3s 340ms/step - loss: 0.1448 - accuracy: 0.9367 - val_loss: 0.0754 - val_accuracy: 0.9750
# Epoch 106/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.1036 - accuracy: 0.9533 - val_loss: 0.0998 - val_accuracy: 0.9750
# Epoch 107/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0852 - accuracy: 0.9667 - val_loss: 0.1477 - val_accuracy: 0.9500
# Epoch 108/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1114 - accuracy: 0.9567 - val_loss: 0.4218 - val_accuracy: 0.8250
# Epoch 109/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1550 - accuracy: 0.9433 - val_loss: 0.3023 - val_accuracy: 0.9000
# Epoch 110/500
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0719 - accuracy: 0.9767 - val_loss: 0.0252 - val_accuracy: 0.9750
# Epoch 111/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.2113 - accuracy: 0.9233 - val_loss: 0.0565 - val_accuracy: 0.9750
# Epoch 112/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1440 - accuracy: 0.9533 - val_loss: 0.0664 - val_accuracy: 0.9750
# Epoch 113/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.1438 - accuracy: 0.9500 - val_loss: 0.3626 - val_accuracy: 0.8500
# Epoch 114/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.1188 - accuracy: 0.9633 - val_loss: 0.0416 - val_accuracy: 0.9750
# Epoch 115/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1844 - accuracy: 0.9233 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 116/500
# 10/10 [==============================] - 4s 385ms/step - loss: 0.1208 - accuracy: 0.9700 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 117/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0918 - accuracy: 0.9767 - val_loss: 0.0796 - val_accuracy: 0.9500
# Epoch 118/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1045 - accuracy: 0.9400 - val_loss: 0.3401 - val_accuracy: 0.8750
# Epoch 119/500
# 10/10 [==============================] - 4s 357ms/step - loss: 0.1023 - accuracy: 0.9633 - val_loss: 0.0980 - val_accuracy: 0.9500
# Epoch 120/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0882 - accuracy: 0.9667 - val_loss: 0.4600 - val_accuracy: 0.8250
# Epoch 121/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1304 - accuracy: 0.9400 - val_loss: 0.0597 - val_accuracy: 0.9750
# Epoch 122/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1374 - accuracy: 0.9400 - val_loss: 0.1332 - val_accuracy: 0.9500
# Epoch 123/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1547 - accuracy: 0.9233 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 124/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0905 - accuracy: 0.9733 - val_loss: 0.1509 - val_accuracy: 0.9500
# Epoch 125/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0843 - accuracy: 0.9667 - val_loss: 0.2721 - val_accuracy: 0.9250
# Epoch 126/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.1064 - accuracy: 0.9533 - val_loss: 0.1005 - val_accuracy: 0.9750
# Epoch 127/500
# 10/10 [==============================] - 4s 393ms/step - loss: 0.0625 - accuracy: 0.9800 - val_loss: 0.1561 - val_accuracy: 0.9500
# Epoch 128/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.0974 - accuracy: 0.9567 - val_loss: 0.2003 - val_accuracy: 0.9000
# Epoch 129/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0529 - accuracy: 0.9767 - val_loss: 0.0998 - val_accuracy: 0.9500
# Epoch 130/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0907 - accuracy: 0.9700 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 131/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1110 - accuracy: 0.9633 - val_loss: 0.1777 - val_accuracy: 0.9500
# Epoch 132/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0921 - accuracy: 0.9633 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 133/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0812 - accuracy: 0.9700 - val_loss: 0.2210 - val_accuracy: 0.9250
# Epoch 134/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.1070 - accuracy: 0.9600 - val_loss: 0.0642 - val_accuracy: 0.9750
# Epoch 135/500
# 10/10 [==============================] - 4s 345ms/step - loss: 0.0984 - accuracy: 0.9633 - val_loss: 0.1290 - val_accuracy: 0.9500
# Epoch 136/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0656 - accuracy: 0.9767 - val_loss: 0.0815 - val_accuracy: 0.9500
# Epoch 137/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0894 - accuracy: 0.9733 - val_loss: 0.1952 - val_accuracy: 0.9000
# Epoch 138/500
# 10/10 [==============================] - 4s 358ms/step - loss: 0.1201 - accuracy: 0.9433 - val_loss: 0.3785 - val_accuracy: 0.9000
# Epoch 139/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1024 - accuracy: 0.9633 - val_loss: 1.3497 - val_accuracy: 0.6250
# Epoch 140/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.2260 - accuracy: 0.9167 - val_loss: 0.1903 - val_accuracy: 0.9500
# Epoch 141/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1350 - accuracy: 0.9433 - val_loss: 0.2164 - val_accuracy: 0.9000
# Epoch 142/500
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2171 - accuracy: 0.9167 - val_loss: 0.1685 - val_accuracy: 0.9000
# Epoch 143/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.1100 - accuracy: 0.9733 - val_loss: 0.1078 - val_accuracy: 0.9500
# Epoch 144/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1084 - accuracy: 0.9600 - val_loss: 0.0808 - val_accuracy: 0.9750
# Epoch 145/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1472 - accuracy: 0.9467 - val_loss: 0.1857 - val_accuracy: 0.9000
# Epoch 146/500
# 10/10 [==============================] - 4s 456ms/step - loss: 0.0809 - accuracy: 0.9733 - val_loss: 0.1086 - val_accuracy: 0.9750
# Epoch 147/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0956 - accuracy: 0.9667 - val_loss: 0.3421 - val_accuracy: 0.9000
# Epoch 148/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.0960 - accuracy: 0.9667 - val_loss: 0.1592 - val_accuracy: 0.9500
# Epoch 149/500
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0622 - accuracy: 0.9767 - val_loss: 0.1597 - val_accuracy: 0.9250
# Epoch 150/500
# 10/10 [==============================] - 4s 380ms/step - loss: 0.0937 - accuracy: 0.9633 - val_loss: 0.0920 - val_accuracy: 0.9750
# Epoch 151/500
# 10/10 [==============================] - 4s 348ms/step - loss: 0.1101 - accuracy: 0.9633 - val_loss: 0.0895 - val_accuracy: 0.9500
# Epoch 152/500
# 10/10 [==============================] - 4s 400ms/step - loss: 0.0675 - accuracy: 0.9800 - val_loss: 0.1180 - val_accuracy: 0.9500
# Epoch 153/500
# 10/10 [==============================] - 4s 359ms/step - loss: 0.0898 - accuracy: 0.9733 - val_loss: 0.3171 - val_accuracy: 0.8750
# Epoch 154/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0897 - accuracy: 0.9600 - val_loss: 0.3161 - val_accuracy: 0.8750
# Epoch 155/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.0496 - accuracy: 0.9800 - val_loss: 0.1474 - val_accuracy: 0.9500
# Epoch 156/500
# 10/10 [==============================] - 4s 388ms/step - loss: 0.1233 - accuracy: 0.9633 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 157/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1394 - accuracy: 0.9467 - val_loss: 0.1194 - val_accuracy: 0.9250
# Epoch 158/500
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0753 - accuracy: 0.9633 - val_loss: 0.1204 - val_accuracy: 0.9000
# Epoch 159/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.0769 - accuracy: 0.9767 - val_loss: 0.2196 - val_accuracy: 0.9500
# Epoch 160/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0690 - accuracy: 0.9733 - val_loss: 0.1091 - val_accuracy: 0.9500
# Epoch 161/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1005 - accuracy: 0.9600 - val_loss: 0.2892 - val_accuracy: 0.8500
# Epoch 162/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0887 - accuracy: 0.9667 - val_loss: 0.3368 - val_accuracy: 0.8750
# Epoch 163/500
# 10/10 [==============================] - 3s 350ms/step - loss: 0.1081 - accuracy: 0.9667 - val_loss: 0.0668 - val_accuracy: 0.9500
# Epoch 164/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0680 - accuracy: 0.9833 - val_loss: 0.2058 - val_accuracy: 0.9000
# Epoch 165/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0552 - accuracy: 0.9800 - val_loss: 0.1417 - val_accuracy: 0.9500
# Epoch 166/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.0963 - accuracy: 0.9567 - val_loss: 0.0800 - val_accuracy: 0.9750
# Epoch 167/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.1059 - accuracy: 0.9733 - val_loss: 0.1870 - val_accuracy: 0.9750
# Epoch 168/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1168 - accuracy: 0.9700 - val_loss: 0.1209 - val_accuracy: 0.9500
# Epoch 169/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0760 - accuracy: 0.9767 - val_loss: 0.1034 - val_accuracy: 0.9750
# Epoch 170/500
# 10/10 [==============================] - 4s 374ms/step - loss: 0.0605 - accuracy: 0.9867 - val_loss: 0.0265 - val_accuracy: 0.9750
# Epoch 171/500
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0689 - accuracy: 0.9800 - val_loss: 0.1323 - val_accuracy: 0.9500
# Epoch 172/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0621 - accuracy: 0.9733 - val_loss: 0.3259 - val_accuracy: 0.8750
# Epoch 173/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0609 - accuracy: 0.9667 - val_loss: 0.1123 - val_accuracy: 0.9500
# Epoch 174/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.1000 - accuracy: 0.9600 - val_loss: 0.2433 - val_accuracy: 0.9500
# Epoch 175/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0730 - accuracy: 0.9667 - val_loss: 0.0331 - val_accuracy: 0.9750
# Epoch 176/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1037 - accuracy: 0.9667 - val_loss: 0.2578 - val_accuracy: 0.9500
# Epoch 177/500
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0497 - accuracy: 0.9767 - val_loss: 0.0756 - val_accuracy: 0.9750
# Epoch 178/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0696 - accuracy: 0.9700 - val_loss: 0.0295 - val_accuracy: 0.9750
# Epoch 179/500
# 10/10 [==============================] - 4s 378ms/step - loss: 0.0816 - accuracy: 0.9700 - val_loss: 0.0244 - val_accuracy: 0.9750
# Epoch 180/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0621 - accuracy: 0.9767 - val_loss: 0.1046 - val_accuracy: 0.9500
# Epoch 181/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0722 - accuracy: 0.9733 - val_loss: 0.3198 - val_accuracy: 0.9000
# Epoch 182/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.1184 - accuracy: 0.9567 - val_loss: 0.0371 - val_accuracy: 1.0000
# Epoch 183/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0895 - accuracy: 0.9733 - val_loss: 0.1219 - val_accuracy: 0.9250
# Epoch 184/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0900 - accuracy: 0.9567 - val_loss: 0.1213 - val_accuracy: 0.9500
# Epoch 185/500
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1267 - accuracy: 0.9567 - val_loss: 0.2709 - val_accuracy: 0.9250
# Epoch 186/500
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0781 - accuracy: 0.9800 - val_loss: 0.1188 - val_accuracy: 0.9250
# Epoch 187/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.0661 - accuracy: 0.9767 - val_loss: 0.1907 - val_accuracy: 0.9500
# Epoch 188/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0929 - accuracy: 0.9600 - val_loss: 0.0844 - val_accuracy: 0.9500
# Epoch 189/500
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0647 - accuracy: 0.9667 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 190/500
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0627 - accuracy: 0.9700 - val_loss: 0.0585 - val_accuracy: 0.9750
# Epoch 191/500
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0801 - accuracy: 0.9733 - val_loss: 0.0253 - val_accuracy: 0.9750
# Epoch 192/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0717 - accuracy: 0.9833 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 193/500
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0422 - accuracy: 0.9833 - val_loss: 0.1082 - val_accuracy: 0.9500
# Epoch 194/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.1270 - accuracy: 0.9733 - val_loss: 0.0766 - val_accuracy: 0.9750
# Epoch 195/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0561 - accuracy: 0.9800 - val_loss: 0.1154 - val_accuracy: 0.9500
# Epoch 196/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0498 - accuracy: 0.9833 - val_loss: 0.0686 - val_accuracy: 0.9750
# Epoch 197/500
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0686 - accuracy: 0.9800 - val_loss: 0.2514 - val_accuracy: 0.9250
# Epoch 198/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0828 - accuracy: 0.9667 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 199/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0630 - accuracy: 0.9800 - val_loss: 0.0662 - val_accuracy: 0.9750
# Epoch 200/500
# 10/10 [==============================] - 4s 372ms/step - loss: 0.0497 - accuracy: 0.9800 - val_loss: 0.1306 - val_accuracy: 0.9500
# Epoch 201/500
# 10/10 [==============================] - 4s 357ms/step - loss: 0.0542 - accuracy: 0.9867 - val_loss: 0.1641 - val_accuracy: 0.9500
# Epoch 202/500
# 10/10 [==============================] - 4s 373ms/step - loss: 0.0434 - accuracy: 0.9833 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 203/500
# 10/10 [==============================] - 4s 402ms/step - loss: 0.0548 - accuracy: 0.9767 - val_loss: 0.1817 - val_accuracy: 0.9500
# Epoch 204/500
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0498 - accuracy: 0.9733 - val_loss: 0.1794 - val_accuracy: 0.9750
# Epoch 205/500
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0453 - accuracy: 0.9800 - val_loss: 0.1314 - val_accuracy: 0.9500
# Epoch 206/500
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0447 - accuracy: 0.9800 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 207/500
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0973 - accuracy: 0.9633 - val_loss: 0.0859 - val_accuracy: 0.9500
# Epoch 208/500
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0607 - accuracy: 0.9800 - val_loss: 0.1207 - val_accuracy: 0.9250
# Epoch 209/500
# 10/10 [==============================] - 4s 457ms/step - loss: 0.0460 - accuracy: 0.9800 - val_loss: 0.0716 - val_accuracy: 0.9750
# Epoch 210/500
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0399 - accuracy: 0.9833 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 211/500
# 10/10 [==============================] - 4s 369ms/step - loss: 0.0508 - accuracy: 0.9833 - val_loss: 0.1604 - val_accuracy: 0.9500
# Epoch 212/500
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0483 - accuracy: 0.9800 - val_loss: 0.1511 - val_accuracy: 0.8750
# Epoch 213/500
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0434 - accuracy: 0.9800 - val_loss: 0.1002 - val_accuracy: 0.9500
# Epoch 214/500
# 10/10 [==============================] - 4s 376ms/step - loss: 0.0561 - accuracy: 0.9800 - val_loss: 0.1969 - val_accuracy: 0.9500
# Epoch 215/500
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0482 - accuracy: 0.9800 - val_loss: 0.0927 - val_accuracy: 0.9500
# Epoch 216/500
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0885 - accuracy: 0.9733 - val_loss: 0.1647 - val_accuracy: 0.9250
# Epoch 217/500
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0481 - accuracy: 0.9833 - val_loss: 0.0928 - val_accuracy: 0.9500
# Epoch 218/500
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0738 - accuracy: 0.9633 - val_loss: 0.0924 - val_accuracy: 0.9500
# Epoch 219/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9933Reached 99% accuracy so cancelling training!
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0274 - accuracy: 0.9933 - val_loss: 0.0342 - val_accuracy: 1.0000

# %% [markdown]
# ## Plotting Accuracy and Loss Functions

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss functions
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn
y_pred = model.predict(validation_generator, 20)
print('Confusion Matrix')
y_predicted_labels = y_pred > 0.5

size = np.size(y_predicted_labels)
y_predicted_labels = y_predicted_labels.reshape(size, )

for i in range (1, 5):
  total = i * size // 4
  mid = 49
  start = mid-((total+1)//2)+1
  end = mid+((total+1)//2)
  cm = tf.math.confusion_matrix(labels=validation_generator.labels[start:end],predictions=y_predicted_labels[start:end])

  # Calculate accuracy
  cm_np = cm.numpy()
  conf_acc = (cm_np[0, 0] + cm_np[1, 1])/ np.sum(cm_np) * 100
  print("Accuracy for", str(total), "Test Data = ", conf_acc)

  # Plot the confusion matrix
  plt.figure(figsize = (10,7))
  seaborn.heatmap(cm, annot=True, fmt='d')
  plt.title("Confusion Matrix for " + str(total) + " Test Data")
  plt.xlabel('Predicted')
  plt.ylabel('Expected')
# Out:
# Confusion Matrix
# Accuracy for 25 Test Data =  48.0
# Accuracy for 50 Test Data =  46.93877551020408
# Accuracy for 75 Test Data =  52.0
# Accuracy for 100 Test Data =  52.52525252525253

# %% [markdown]
# ## Saving the model

# %%
# Save and convert the model (Used for deploying in web application)
model.save('image.h5')
print("Saved the model successfully")

# !apt-get -qq install virtualenv
# !virtualenv -p python3 venv
# !source venv/bin/activate
# !pip install -q tensorflowjs
# !tensorflowjs_converter --input_format=keras /content/model/image_model.h5 /content/image_model
print("Model converted to JSON successfully")
# Out:
# Saved the model successfully
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_9.0.1-2.3~ubuntu1.18.04.5_all.deb ...
# Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-virtualenv.
# Preparing to unpack .../python3-virtualenv_15.1.0+ds-1.1_all.deb ...
# Unpacking python3-virtualenv (15.1.0+ds-1.1) ...
# Selecting previously unselected package virtualenv.
# Preparing to unpack .../virtualenv_15.1.0+ds-1.1_all.deb ...
# Unpacking virtualenv (15.1.0+ds-1.1) ...
# Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python3-virtualenv (15.1.0+ds-1.1) ...
# Setting up virtualenv (15.1.0+ds-1.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Already using interpreter /usr/bin/python3
# Using base prefix '/usr'
# New python executable in /content/venv/bin/python3
# Also creating executable in /content/venv/bin/python
# Installing setuptools, pkg_resources, pip, wheel...done.
#      |████████████████████████████████| 77 kB 6.7 MB/s
#      |████████████████████████████████| 40 kB 7.4 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorflowjs_converter", line 8, in <module>
#     sys.exit(pip_main())
#   File "/usr/local/lib/python3.7/dist-packages/tensorflowjs/converters/converter.py", line 813, in pip_main
#     main([' '.join(sys.argv[1:])])
#   File "/usr/local/lib/python3.7/dist-packages/tensorflowjs/converters/converter.py", line 817, in main
#     convert(argv[0].split(' '))
#   File "/usr/local/lib/python3.7/dist-packages/tensorflowjs/converters/converter.py", line 804, in convert
#     weight_shard_size_bytes, metadata_map)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflowjs/converters/converter.py", line 501, in _dispatch_converter
#     metadata=metadata_map)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflowjs/converters/converter.py", line 76, in dispatch_keras_h5_to_tfjs_layers_model_conversion
#     raise ValueError('Nonexistent path to HDF5 file: %s' % h5_path)
# ValueError: Nonexistent path to HDF5 file: /content/model/image_model.h5
# Model converted to JSON successfully

# %% [markdown]
# ## Sample Example

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))
   
for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)  
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
# Out:
#      <input type="file" id="files-f48965c9-bf07-47be-86a5-48a6343b99e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f48965c9-bf07-47be-86a5-48a6343b99e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aadhar (3).jpg to aadhar (3).jpg
# [1.]
# aadhar (3).jpg - Sensitive
